# %%
import pandas as pd

# %%
data = {'name':['jack' , 'sara' , 'sam'],
        'sex':['male' , 'female' , 'male'],
        'age': [23, 25, 29],
        'address': [123, 256, 564]
        }

# %%
df = pd.DataFrame(data, index = [0,1,2])
df
# Out:
#    name     sex  age  address
# 0  jack    male   23      123
# 1  sara  female   25      256
# 2   sam    male   29      564

# %%
import pandas as pd

# %%
df = pd.read_csv("/zomato.csv" , encoding = "latin-1")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df[df["Restaurant Name"]=="Foodbymom"]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
print("number of rows are", df.shape[0])
print("number of column are",df.shape[1] )
# Out:
# number of rows are 9551
# number of column are 21

# %%
import seaborn as sns

# %%
df=df. isnull().sum()

# %%
df.head()
# Out:
# Restaurant ID      0
# Restaurant Name    0
# Country Code       0
# City               0
# Address            0
# dtype: int64

# %%
mydict = {
    'dates':['02-01-12', '03-01-12', '04-01-12', '05-01-12', '06-01-12'],
    'day':['sunny','hot','sunny','hot', 'rainy'],
    'wind-speed':[12,34,45,56,67],
    'temp':[45,46,47,48,49],
}
df=pd.DataFrame(mydict)

# %%
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12    hot          34    46
# 2  04-01-12  sunny          45    47
# 3  05-01-12    hot          56    48
# 4  06-01-12  rainy          67    49

# %%
d1=df[df['temp']>9]

# %%
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12    hot          34    46
# 2  04-01-12  sunny          45    47
# 3  05-01-12    hot          56    48
# 4  06-01-12  rainy          67    49

# %%
df2 =  pd.read_csv("/content/zomato.csv" , encoding='latin1')

# %%
df2.head(4)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# ...

# %%
df2.tail(2)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude         Cuisines  ...  \
# 9549  Kuruí_eôme, ÛÁstanbul  29.036019  41.057979  Restaurant Cafe  ...
# 9550         Moda, ÛÁstanbul  29.026016  40.984776             Cafe  ...
#
#               Currency Has Table booking Has Online delivery  \
# 9549  Turkish Lira(TL)                No                  No
# 9550  Turkish Lira(TL)                No                  No
#
#      Is delivering now Switch to order menu Price range  Aggregate rating  \
# ...

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df2.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.shape
# Out:
# (5, 4)

# %%
df2[df2['Has Online delivery']=="Yes"]
# Out:
#       Restaurant ID                   Restaurant Name  Country Code  \
# 565         5704255            Famous Dave's Barbecue           214
# 566         5701978                    Pizza Di Rocco           214
# 571         5700052  Cho Gao - Crowne Plaza Abu Dhabi           214
# 572         5702418                            Gazebo           214
# 573         5700386   Sangeetha Vegetarian Restaurant           214
# ...             ...                               ...           ...
# 9166          11371                           Chili's             1
# 9168       18292672                        Blue Water             1
# 9170        6507967                   Tales & Spirits             1
# 9171        6506206           18 Degrees Resto Lounge             1
# 9194          96814                    Saffron Mantra             1
#
#               City                                            Address  \
# 565      Abu Dhabi  Near The One, Level 3, Abu Dhabi Mall, Tourist...
# ...

# %%
df2[df2["Restaurant Name"]=="Baltzar"]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
df2[df2["City"]=='Pune']
# Out:
#       Restaurant ID          Restaurant Name  Country Code  City  \
# 9154        6508323        The Urban Foundry             1  Pune
# 9155       18383095                Teddy Boy             1  Pune
# 9156       18378852        Effingut Brewerkz             1  Pune
# 9157          13231               Le Plaisir             1  Pune
# 9158       18354483               Farzi Cafe             1  Pune
# 9159       18383076        Mineority By Saby             1  Pune
# 9160        6505309     The Little Next Door             1  Pune
# 9161        6504409        Effingut Brewerkz             1  Pune
# 9162       18350020                    Kargo             1  Pune
# 9163        6508117         Sautí©ed Stories             1  Pune
# 9164       18417624          The Sassy Spoon             1  Pune
# 9165        6505564  German Bakery Wunderbar             1  Pune
# 9166          11371                  Chili's             1  Pune
# ...

# %%
print(df2.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df2[df2['Has Online delivery']=="No"]
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2[df2['Has Online delivery']=="Yes"]
# Out:
#       Restaurant ID                   Restaurant Name  Country Code  \
# 565         5704255            Famous Dave's Barbecue           214
# 566         5701978                    Pizza Di Rocco           214
# 571         5700052  Cho Gao - Crowne Plaza Abu Dhabi           214
# 572         5702418                            Gazebo           214
# 573         5700386   Sangeetha Vegetarian Restaurant           214
# ...             ...                               ...           ...
# 9166          11371                           Chili's             1
# 9168       18292672                        Blue Water             1
# 9170        6507967                   Tales & Spirits             1
# 9171        6506206           18 Degrees Resto Lounge             1
# 9194          96814                    Saffron Mantra             1
#
#               City                                            Address  \
# 565      Abu Dhabi  Near The One, Level 3, Abu Dhabi Mall, Tourist...
# ...

# %%
df2[df2['Locality']=='Moda']
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address Locality  \
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...     Moda
#
#      Locality Verbose  Longitude   Latitude Cuisines  ...          Currency  \
# 9550  Moda, ÛÁstanbul  29.026016  40.984776     Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 9550   Very Good   591
#
# [1 rows x 21 columns]

# %%
df2[df2['Average Cost for two']==800000]
# Out:
#       Restaurant ID           Restaurant Name  Country Code     City  \
# 9283        7402935                      Skye            94  Jakarta
# 9284        7410290  Satoo - Hotel Shangri-La            94  Jakarta
#
#                                                 Address  \
# 9283  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 9284               Hotel Shangri-La, Jl. Jend. Sudirman
#
#                            Locality                        Locality Verbose  \
# 9283  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 9284     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
#
#        Longitude  Latitude                    Cuisines  ...  \
# 9283  106.821999 -6.196778        Italian, Continental  ...
# 9284  106.818961 -6.203292  Asian, Indonesian, Western  ...
#
#                     Currency Has Table booking Has Online delivery  \
# 9283  Indonesian Rupiah(IDR)                No                  No
# ...

# %%
import pandas as pd

# %%
list = ['snake', 'rat', 'lizard', 'is',
            'reptile']
df = pd.DataFrame(list)
print(df)
# Out:
#          0
# 0    snake
# 1      rat
# 2   lizard
# 3       is
# 4  reptile

# %%
df
# Out:
#          0
# 0    snake
# 1      rat
# 2   lizard
# 3       is
# 4  reptile

# %%
df = pd.read_excel("/content/Country-Code.xlsx")

# %%
df
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df = pd.read_csv("/content/zomato.csv", encoding = "latin-1")

# %%
df[df["City"]=='Pune']
# Out:
#       Restaurant ID          Restaurant Name  Country Code  City  \
# 9154        6508323        The Urban Foundry             1  Pune
# 9155       18383095                Teddy Boy             1  Pune
# 9156       18378852        Effingut Brewerkz             1  Pune
# 9157          13231               Le Plaisir             1  Pune
# 9158       18354483               Farzi Cafe             1  Pune
# 9159       18383076        Mineority By Saby             1  Pune
# 9160        6505309     The Little Next Door             1  Pune
# 9161        6504409        Effingut Brewerkz             1  Pune
# 9162       18350020                    Kargo             1  Pune
# 9163        6508117         Sautí©ed Stories             1  Pune
# 9164       18417624          The Sassy Spoon             1  Pune
# 9165        6505564  German Bakery Wunderbar             1  Pune
# 9166          11371                  Chili's             1  Pune
# ...

# %%
df[df['Rating text']=='Excellent']
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 3           6318506                                      Ooma           162
# 4           6314302                               Sambo Kojin           162
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila           162
# ...             ...                                       ...           ...
# 9537        5904116                       J'adore Chocolatier           208
# 9538        5901782                                 Starbucks           208
# 9540        5927248                          Draft Gastro Pub           208
# 9543        5916085                              Dem Karakí_y           208
# 9544        5915547                     Karakí_y Gí_llí_oÛôlu           208
#
# ...

# %%
df1 = pd.merge(df,df,"left")

# %%
df = pd.read_excel("/content/Country-Code.xlsx")
df = pd.read_csv("/content/zomato.csv")

df1 = df.merge(df, how='left', left_on='gene', right_on='gene')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-53-14bad72ff31e> in <cell line: 2>()
#       1 df = pd.read_excel("/content/Country-Code.xlsx")
# ----> 2 df = pd.read_csv("/content/zomato.csv")
#       3
#       4 df1 = df.merge(df, how='left', left_on='gene', right_on='gene')
#
# ...

# %%
df1[df1['Rating text']=='Excellent']['Country'].value_counts().head(5).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
